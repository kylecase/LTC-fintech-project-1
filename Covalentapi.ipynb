# %%
# Initial imports
import os
import requests
import json
from dotenv import load_dotenv
import pandas as pd

# %%
# Load .env environment variables
load_dotenv()
# Out:
# True

# %%
#Set CovalentHQ API Key and check length = 32
covalenthq_api_key = os.getenv("COVALENTHQ_API_KEY")
len(covalenthq_api_key)
# Out:
# 32

# %%
#Set Blockchain and Dex_Name parameters for the covalent api pull
chain_id = 1
dex_name = 'uniswap_v2'

# %%
#Data pull URL with parameters, but not api key
cov_coin_list = f"https://api.covalenthq.com/v1/{chain_id}/xy=k/{dex_name}/tokens/?quote-currency=USD&format=JSON&page-size=1000000000&key="

# %%
#Response Data Collection from URL+API_Key 
response_coin_list = requests.get(cov_coin_list + covalenthq_api_key).json()

# %%
#Create DataFrame from API pull
coin_table_ticker = response_coin_list['data']['items']
coin_table_df = pd.DataFrame(coin_table_ticker)

# %%
#Data Cleanup - Check Nulls
coin_table_df.isnull().sum()
# Out:
# chain_name                 0
# chain_id                   0
# dex_name                   0
# contract_address           0
# contract_name              0
# total_liquidity            0
# total_volume_24h           0
# logo_url                   0
# contract_ticker_symbol     0
# contract_decimals          0
# swap_count_24h             0
# quote_rate                18
# total_liquidity_quote     18
# total_volume_24h_quote    18
# dtype: int64

# %%
#Data Cleanup - Drop Nulls
coin_table_df.dropna()
# Out:
#        chain_name chain_id    dex_name  \
# 0     eth-mainnet        1  uniswap_v2
# 1     eth-mainnet        1  uniswap_v2
# 2     eth-mainnet        1  uniswap_v2
# 3     eth-mainnet        1  uniswap_v2
# 4     eth-mainnet        1  uniswap_v2
# ...           ...      ...         ...
# 5749  eth-mainnet        1  uniswap_v2
# 5750  eth-mainnet        1  uniswap_v2
# 5751  eth-mainnet        1  uniswap_v2
# 5752  eth-mainnet        1  uniswap_v2
# 5753  eth-mainnet        1  uniswap_v2
#
#                                 contract_address      contract_name  \
# 0     0x01ef4c5e33264e6fad98ac30be389a5ab1dbebd2          OLD FLOKI
# 1     0x37b9c078c248f76b1e9e41319a29381ad7907479          yZyxToken
# 2     0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2      Wrapped Ether
# 3     0x57f7169809e0f30c2f3d7332710115c1f9236525          Chameleon
# 4     0x4ef66e564e89a60041eebce4716e142626c2f2f4  UPSTABLE.PROTOCOL
# ...                                          ...                ...
# 5749  0xfef3884b603c33ef8ed4183346e093a173c94da6         MetaMorph
# 5750  0x5fdfe5ee55ae0fb7e0dba3481ea46f22fc92cbbb             McDoge
# 5751  0x2327590bb709f1505b64d1e4573d7c0dcea4350c           Shibgeki
# 5752  0x6adb2e268de2aa1abf6578e4a8119b960e02928f          ShibaDoge
# 5753  0x7e794ed35788b698ae60cefc98ee48015c4876da           Shintama
#
#                        total_liquidity                 total_volume_24h  \
# 0             106444094118194102902774         106444054491647363348293
# 1                 84050005242704549382                            58112
# 2             276781282608126527278954         368665104521401437038591
# 3         5369296597424206566556223915     5427602181805679919274331418
# 4                   577463976766109598               681054283006206600
# ...                                ...                              ...
# 5749           25557333302992996852581            372661949739563279289
# 5750  32123277562737610088451080811626   117222150031400794426407877653
# 5751  31713552763415290963875852564686   601917856343266140211100736726
# 5752  19246331544538369150153016168627  2078683769715333740064588058595
# 5753  11311961553245662261984504605425   308259376197877853566257040298
#
#                                                logo_url  \
# 0     https://logos.covalenthq.com/tokens/0x01ef4c5e...
# 1     https://logos.covalenthq.com/tokens/0x37b9c078...
# 2     https://logos.covalenthq.com/tokens/0xc02aaa39...
# 3     https://logos.covalenthq.com/tokens/0x57f71698...
# 4     https://logos.covalenthq.com/tokens/0x4ef66e56...
# ...                                                 ...
# 5749  https://logos.covalenthq.com/tokens/0xfef3884b...
# 5750  https://logos.covalenthq.com/tokens/0x5fdfe5ee...
# 5751  https://logos.covalenthq.com/tokens/0x2327590b...
# 5752  https://logos.covalenthq.com/tokens/0x6adb2e26...
# 5753  https://logos.covalenthq.com/tokens/0x7e794ed3...
#
#      contract_ticker_symbol  contract_decimals  swap_count_24h    quote_rate  \
# 0                 OLD FLOKI                  9              24  4.212104e-05
# 1                      yZyx                 18               1  4.297790e+07
# 2                      WETH                 18              24  1.846793e+03
# 3                     $CMLN                 18               8  7.367553e-02
# 4                       UPS                  9               6  4.023643e-01
# ...                     ...                ...             ...           ...
# 5749                   METM                 18               2  0.000000e+00
# 5750                 MCDOGE                  9               7  0.000000e+00
# 5751               SHIBGEKI                  9               2  0.000000e+00
# 5752               ShibDoge                  9             669  0.000000e+00
# 5753               SHINTAMA                  9              40  0.000000e+00
#
#       total_liquidity_quote  total_volume_24h_quote
# 0              4.483536e+09            4.483534e+09
# 1              3.612292e+09            2.497532e-06
# 2              5.111577e+08            6.808481e+08
# 3              3.955858e+08            3.998815e+08
# 4              2.323509e+08            2.740319e+08
# ...                     ...                     ...
# 5749           0.000000e+00            0.000000e+00
# 5750           0.000000e+00            0.000000e+00
# 5751           0.000000e+00            0.000000e+00
# 5752           0.000000e+00            0.000000e+00
# 5753           0.000000e+00            0.000000e+00
#
# [5754 rows x 14 columns]

# %%
#Finding the total rows needed to pair the list down to 200 rows
df_len = len(coin_table_df.index)
drop_len = df_len - 200

#Converting numbers saved as string to float
coin_table_df['total_volume_24h'] = coin_table_df['total_volume_24h'].astype(float)
coin_table_df['total_liquidity'] = coin_table_df['total_liquidity'].astype(float)
coin_table_df['quote_rate'] = coin_table_df['quote_rate'].astype(float)
coin_table_df['total_liquidity_quote'] = coin_table_df['total_liquidity_quote'].astype(float)
coin_table_df['total_volume_24h_quote'] = coin_table_df['total_volume_24h_quote'].astype(float)

#Reindexing by top traded coins to drop the less popular coins
coin_table_df = coin_table_df.sort_values('swap_count_24h', ascending=False)
coin_table_df = coin_table_df.reset_index(drop=True)

#Drop all but top 200 traded in the last 24 hours
coin_table_df = coin_table_df.drop(coin_table_df.tail(drop_len).index)

#Preview table
coin_table_df
# Out:
#       chain_name chain_id    dex_name  \
# 0    eth-mainnet        1  uniswap_v2
# 1    eth-mainnet        1  uniswap_v2
# 2    eth-mainnet        1  uniswap_v2
# 3    eth-mainnet        1  uniswap_v2
# 4    eth-mainnet        1  uniswap_v2
# ..           ...      ...         ...
# 495  eth-mainnet        1  uniswap_v2
# 496  eth-mainnet        1  uniswap_v2
# 497  eth-mainnet        1  uniswap_v2
# 498  eth-mainnet        1  uniswap_v2
# 499  eth-mainnet        1  uniswap_v2
#
#                                contract_address         contract_name  \
# 0    0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48              USD Coin
# 1    0xdac17f958d2ee523a2206206994597c13d831ec7            Tether USD
# 2    0xc5fb36dd2fb59d3b98deff88425a3f425ee469ed        Dejitaru Tsuka
# 3    0x90f36d7bfba633f17eccc62ec31c58a9a3c04c2a            PulseFloki
# 4    0x249e38ea4102d0cf8264d3701f1a0e39c4f2dc3b             THE TRUTH
# ..                                          ...                   ...
# 495  0xb8110896d6f6055bb3da35904b8bf040064defd9             BLIND EYE
# 496  0x038a68ff68c393373ec894015816e33ad41bd564                Glitch
# 497  0xd5d86fc8d5c0ea1ac1ac5dfab6e529c9967a45e9            NFT Worlds
# 498  0xa8f340358fc1f87bafb61efdae4e62d5501b571e    Degens In Paradise
# 499  0xa117000000f279d81a1d3cc75430faa017fa5a2e  Aragon Network Token
#
#      total_liquidity  total_volume_24h  \
# 0       1.750107e+14      1.548294e+14
# 1       5.694416e+13      3.987281e+13
# 2       1.274785e+16      3.407852e+17
# 3       1.201884e+24      2.858513e+25
# 4       9.004691e+29      3.400948e+30
# ..               ...               ...
# 495     3.489098e+20      5.123548e+20
# 496     2.778518e+24      4.577770e+24
# 497     5.164225e+23      5.464257e+24
# 498     9.360352e+14      2.071417e+15
# 499     4.494057e+23      2.156890e+23
#
#                                               logo_url contract_ticker_symbol  \
# 0    https://logos.covalenthq.com/tokens/0xa0b86991...                   USDC
# 1    https://logos.covalenthq.com/tokens/0xdac17f95...                   USDT
# 2    https://logos.covalenthq.com/tokens/0xc5fb36dd...                  TSUKA
# 3    https://logos.covalenthq.com/tokens/0x90f36d7b...                   PLSF
# 4    https://logos.covalenthq.com/tokens/0x249e38ea...                    UFO
# ..                                                 ...                    ...
# 495  https://logos.covalenthq.com/tokens/0xb8110896...                      👁
# 496  https://logos.covalenthq.com/tokens/0x038a68ff...                   GLCH
# 497  https://logos.covalenthq.com/tokens/0xd5d86fc8...                   WRLD
# 498  https://logos.covalenthq.com/tokens/0xa8f34035...                    DIP
# 499  https://logos.covalenthq.com/tokens/0xa1170000...                    ANT
#
#      contract_decimals  swap_count_24h    quote_rate  total_liquidity_quote  \
# 0                    6           25908  1.000639e+00           1.751226e+08
# 1                    6           13884  1.000639e+00           5.698055e+07
# 2                    9            7390  5.482313e-02           6.988772e+05
# 3                   18            6772  6.468244e-02           7.774080e+04
# 4                   18            4941  4.869676e-06           4.384992e+06
# ..                 ...             ...           ...                    ...
# 495                  9             227  1.528956e-08           5.334678e+03
# 496                 18             227  1.024139e-01           2.845588e+05
# 497                 18             226  1.018757e-02           5.261088e+03
# 498                  8             226  3.890140e-04           3.641307e+03
# 499                 18             225  1.892101e+00           8.503208e+05
#
#      total_volume_24h_quote
# 0              1.549284e+08
# 1              3.989829e+07
# 2              1.868291e+07
# 3              1.848956e+06
# 4              1.656151e+07
# ..                      ...
# 495            7.833680e+03
# 496            4.688271e+05
# 497            5.566747e+04
# 498            8.058102e+03
# 499            4.081052e+05
#
# [500 rows x 14 columns]

# %%
#Created list of tickers to us as options that can be searched to build custom portfolio
ticker_symbol_list = coin_table_df['contract_ticker_symbol'].tolist()
print(ticker_symbol_list)
# Out:
# ['USDC', 'USDT', 'TSUKA', 'PLSF', 'UFO', 'REKT', 'SHIB', 'CEL', 'MOPS', 'HEX', 'OSAKU', 'X7m105', 'MIZUCHI', 'PLSS', 'Okinami', 'INUS', 'Mikaboshi', 'PEPE', 'LAIKA', 'MASKED', 'LQNTY', 'HDRN', 'PLST', 'CULT', 'RYU', 'ELON', 'AMPL', 'XMON', 'TORN', 'SAITAMA', 'FLOKISV', 'IAPE', 'ARRIVAL', 'PLSCI', 'BONE', 'xFUND', 'DOKI', 'CORSA', 'FUTURA', 'BLACKROCK', 'SUKI', 'WHITE', 'MATIC', 'TAXHAVENINU', 'PLSA', 'Brrr', 'BURNIE', 'YASU', 'SEKAI', 'KIRA', 'ET', 'MERGE', 'BEZOGE', '1908', 'HARU', 'X2Y2', 'MSI', 'QOM', 'STRNGR', 'PZEN', 'PYRO', 'KAIDAN', 'BASED', 'CAW', 'GIGA', 'ANARCHY', 'TSYGAN', 'DEV', 'Koshu', 'DOJIN', 'gay🐟', 'FLOKI', '$flokigold', 'UNI', 'RAMEN', 'HAM', 'PLSSFM', 'RYUTSUKA', '$LSVR', 'MJ12', 'Taoka', 'O', 'k0de', 'PULSE', 'WHITEDAI', 'NLD', 'KINRYU', 'YOSHI', 'DBNB', 'VCASH', 'Dione', 'APULSE', 'Ageless', 'MINER', 'RYUJIN', 'STARL', 'FRAX', 'FXS', 'PLSINU', 'SAND', 'SHEESH', 'BUSS', 'SHINJA', 'UNDEAD', 'KIRIN', 'VOLT', 'Greed', 'VRA', 'Shifu', 'R3D', 'DUCKER', 'BUILD', 'MC', '$PLST', 'ASCENT', 'LUNA', 'M87', 'MPL', 'KISHU', 'BOND', 'RHC', 'CPI', 'PAXG', 'SDAX', 'FLOKIMOTO', 'LEASH', 'EVP', 'PRAXIS', '💤', 'FE', 'RUCKUS', 'KISHIBURNO', 'stETH', 'JŌ', '\U0001f9c8', 'YŌKAI', 'MOLLY', 'Old', 'CHAD', 'T3H', 'YDF', '🦞', 'HOGE', 'ShibDoge', 'YATA', 'ALBT', 'GLM', 'RBRN', 'WOKE', 'Shiryo-Inu', 'KAKUAN', 'MatrixInu', 'ZEN', 'DEON', 'PLSSG', 'LINK', 'WOLVERINU', 'FLX', 'WILD', 'SHABI', '$HASHIHIME', 'WOO', '$SHIBTARU', 'GOVT', 'EYES', '$SK', 'MORE', 'DTAIL', 'TSUKAC', '3DB', 'Orochi', 'KoaCombat', 'KUMA', 'MushMush', 'dOOr', 'TUSD', 'LOOKS', 'TRU', 'Metis', '$Kampos', 'SIDUS', 'SUPER', 'Ikigai', 'ACORN', '$JOY', 'UP', 'TINU', 'Hinomaru', 'SNX', 'WAS', 'AK
H', 'Canto', 'EBI', 'CHINXI', 'VENDETTA', 'CANTO', 'KIBA', 'SFIRES', 'KLEE', 'CIMO', 'RACA', 'LIGHT', 'GRUFF', 'PC', 'ANKR', 'INV', '$GRUUL', 'Meta', 'Orochi', 'SHIFT', '1929', 'CRANEO', 'BLT', 'BlueSparrow', 'HIDDEN', 'OKAMI', 'GMEE', 'SD', 'ATD', '$colR', 'PSHIB', '🎏', 'SEND', 'XDB', 'MLT', 'PEPE+', 'SLEUTH', 'XUSDP', 'IKEUCHI', 'LIGHT', 'Shokunin', 'KIMBA', 'BSI', 'LOSTSKULLS', '1INCH', 'ERN', 'TREASURE', 'CHZ', 'RYUZHIN' ...

# %%
#Created dictionary with ticker name: contract name to have if needed
ticker_name_dict = dict(zip(coin_table_df.contract_ticker_symbol, coin_table_df.contract_name))
dict(zip(coin_table_df.contract_ticker_symbol, coin_table_df.contract_name))
# Out:
# {'USDC': 'USD Coin',
#  'USDT': 'Tether USD',
#  'TSUKA': 'Dejitaru Tsuka',
#  'PLSF': 'PulseFloki',
#  'UFO': 'THE TRUTH',
#  'REKT': 'REKT',
#  'SHIB': 'SHIBA INU',
#  'CEL': 'Celsius',
#  'MOPS': 'Mops',
#  'HEX': 'HEX',
#  'OSAKU': 'The Tale of Osaku',
#  'X7m105': 'X7m105',
#  'MIZUCHI': 'Dejitaru Mizuchi',
#  'PLSS': 'PulseShiba',
#  'Okinami': 'Kanagawa Nami',
#  'INUS': 'MultiPlanetary Inus',
#  'Mikaboshi': 'Amatsu-Mikaboshi',
#  'PEPE': 'PEPEGOLD',
#  'LAIKA': 'LAIKA',
#  'MASKED': 'The Ancient Order',
#  'LQNTY': 'Liquinity',
#  'HDRN': 'Hedron',
#  'PLST': 'Pulse Tsuka',
#  'CULT': 'Cult DAO',
#  'RYU': 'Dejitaru Ryu',
#  'ELON': 'Dogelon',
#  'AMPL': 'Ampleforth',
#  'XMON': 'XMON',
#  'TORN': 'TornadoCash',
#  'SAITAMA': 'Saitama Inu',
#  'FLOKISV': 'Floki SV',
#  'IAPE': 'IA',
#  'ARRIVAL': 'ARRIVAL',
#  'PLSCI': 'PulseCliffordInu',
#  'BONE': 'BONE SHIBASWAP',
#  'xFUND': 'unification.com/xfund',
#  'DOKI': 'Okidoki Social',
#  'CORSA': 'CORSA',
#  'FUTURA': 'Futura',
#  'BLACKROCK': 'Black Rock',
#  'SUKI': 'SUKI',
#  'WHITE': 'White Ethereum',
#  'MATIC': 'Matic Token',
#  'TAXHAVENINU': 'Tax Haven Inu',
#  'PLSA': 'PulseApeCoin',
#  'Brrr': 'Brrr',
#  'BURNIE': 'Burnie',
#  'YASU': 'YASU',
#  'SEKAI': 'Shin Sekai',
#  'KIRA': 'A Dark Hunter',
#  'ET': 'THE ONE QUESTION',
#  'MERGE': 'Merge',
#  'BEZOGE': 'Bezoge Earth',
#  '1908': 'Tunguska',
#  'HARU': 'HARU',
#  'X2Y2': 'X2Y2Token',
#  'MSI': 'Martin Shkreli Inu',
#  'QOM': 'Shiba Predator',
#  'STRNGR': 'Stronger',
#  'PZEN': 'PLSZEN',
#  'PYRO': 'PyroMatic',
#  'KAIDAN': 'Yotsuya Kaidan',
#  'BASED': 'Based',
#  'CAW': 'A Hunters Dream',
#  'GIGA': 'GigaSwap',
#  'ANARCHY': 'Anarchy',
#  'TSYGAN': 'The Real TSYGAN',
#  'DEV': 'Dev Doing Something',
#  'Koshu': 'Koshu Misaka',
#  'DOJIN': 'Dejitaru Dojin',
#  'gay🐟': 'gay fish',
#  'FLOKI': 'FLOKI',
#  '$flokigold': 'Floki Gold',
#  'UNI': 'Uniswap',
#  'RAMEN': 'Shio Ramen',
#  'HAM': 'Ham',
#  'PLSSFM': 'PulseSafeMoon',
#  'RYUTSUKA': 'RYUUKO TSUKA',
#  '$LSVR': 'LASREVER',
#  'MJ12': 'MAJESTIC12',
#  'Taoka': 'The Burnt Shiba',
#  'O': 'Childhoods End',
#  'k0de': 'The $k0de',
#  'PULSE': 'Pulse Inu',
#  'WHITEDAI': 'WHITE DAI',
#  'NLD': 'Natural',
#  'KINRYU': 'Teh Golden Dragon',
#  'YOSHI': 'Yoshitora Inu',
#  'DBNB': 'DecentraBNB',
#  'VCASH': 'void.cash',
#  'Dione': 'Dione',
#  'APULSE': 'Anime Pulse',
#  'Ageless': 'Fountain of Youth',
#  'MINER': 'Meta Miner',
#  'RYUJIN': 'Doragon Ryujin',
#  'STARL': 'StarLink',
#  'FRAX': 'Frax',
#  'FXS': 'Frax Share',
#  'PLSINU': 'PULSE INU',
#  'SAND': 'SAND',
#  'SHEESH': 'SHEESH',
#  'BUSS': 'BUSSIN',
#  'SHINJA': 'Shibnobi',
#  'UNDEAD': 'Undead Blocks',
#  'KIRIN': 'Dejitura Kirin',
#  'VOLT': 'Volt Inu',
#  'Greed': 'Mamon',
#  'VRA': 'VERA',
#  'Shifu': 'Shibfan',
#  'R3D': 'SYST3MS',
#  'DUCKER': 'Duckereum',
#  'BUILD': 'Gr33n',
#  'MC': 'Merit Circle',
#  '$PLST': '$PULSE TSUKA',
#  'ASCENT': 'The Ascent',
#  'LUNA': 'Wrapped LUNA Token',
#  'M87': 'MESSIER',
#  'MPL': 'Maple Token',
#  'KISHU': 'Kishu Inu',
#  'BOND': 'BarnBridge Governance Token',
#  'RHC': 'Robinhood Capital',
#  'CPI': 'Can Pump Immediately',
#  'PAXG': 'Paxos Gold',
#  'SDAX': 'SilverDAX',
#  'FLOKIMOTO': 'Satoshi Flokomoto',
#  'LEASH': 'DOGE KILLER',
#  'EVP': 'EVERPOOL',
#  'PRAXIS': 'Modus Operandi',
#  '💤': 'Slept On',
#  'FE': 'Fire Element',
#  'RUCKUS': 'The Disturbance',
#  'KISHIBURNO': 'Kishimoto redux',
#  'stETH': 'Liquid staked Ether 2.0',
#  'JŌ': 'Jō Gurowā',
#  '\U0001f9c8': 'Butter Inu',
#  'YŌKAI': 'Ungaikyō',
#  'MOLLY': 'MOLLY INU',
#  'Old': 'TheOldMarket',
#  'CHAD': 'CHAD',
#  'T3H': 'T3H',
#  'YDF': 'Yieldification',
#  '🦞': 'Lobster Inu',
#  'HOGE': 'hoge.finance',
#  'ShibDoge': 'ShibaDoge',
#  'YATA': 'Yata no Karasu',
#  'ALBT': 'AllianceBlock Token',
#  'GLM': 'Golem Network Token',
#  'RBRN': 'Reborn',
#  'WOKE': 'INSOMNIA',
#  'Shiryo-Inu': 'Shiryo-Inu',
#  'KAKUAN': '10 Bulls',
#  'MatrixInu': 'Matrix Inu',
#  'ZEN': 'At One Within',
#  'DEON': 'Decentralized Onion',
#  'PLSSG': 'PulseSquidGame',
#  'LINK': 'ChainLink Token',
#  'WOLVERINU': 'WOLVERINU',
#  'FLX': 'Flex Ungovernance Token',
#  'WILD': 'Wilder',
#  'SHABI': 'Shabi Inu',
#  '$HASHIHIME': 'Uji-no-Hashihime',
#  'WOO': 'Wootrade Network',
#  '$SHIBTARU': 'Shibtaru',
#  'GOVT': 'Govt',
#  'EYES': 'The Watchers',
#  '$SK': 'ShibaKombat',
#  'MORE': 'More',
#  'DTAIL': 'Dragon Tail',
#  'TSUKAC': 'Tsuka Chain',
#  '3DB': 'Third Degree Burn',
#  'Orochi': 'The Eight Headed Dragon',
#  'KoaCombat': 'KoaCombat',
#  'KUMA': 'Kuma Inu',
#  'MushMush': 'MushMushKing',
#  'dOOr': 'dOOr',
#  'TUSD': 'TrueUSD',
#  'LOOKS': 'LooksRare Token',
#  'TRU': 'Truebit',
#  'Metis': 'Metis Token',
#  '$Kampos': 'Kampos',
#  'SIDUS': 'SIDUS',
#  'SUPER': 'SuperFarm',
#  'Ikigai': 'Reason For Being',
#  'ACORN': 'Squirrel With A Gun',
#  '$JOY': 'Joy Token',
#  'UP': 'Price Go Up',
#  'TINU': 'Telegram Inu',
#  'Hinomaru': 'Rising Sun',
#  'SNX': 'Synthetix Network Token',
#  'WAS': 'Wasder Token',
#  'AKITA': 'Akita Inu',
#  'HYA': 'Hydra Token',
#  '🔥🦞': 'Burnt Lobster',
#  'DAMN': 'Damn',
#  'Tsuru': 'Tsuru no Ongaeshi',
#  'ZRO': 'PROTOCOL ZERO',
#  'SOA': 'Sons of Anarchy',
#  'Suwa': 'Shinshu Suwako',
#  'D3AD': 'Stay Alive',
#  'SEKI': 'Sessho Seki',
#  'FOMO': 'Fear Of Missing Out',
#  'DD': 'Doge Daniels',
#  'KAISEI': 'Gaifu Kaisei',
#  'HYPER': 'Hypercycle',
#  'WBTC': 'Wrapped BTC',
#  'CMNR': 'Commoner',
#  '$MAX': 'Max Bidding',
#  'WHALING': 'Mega Whale',
#  'Sturdy': 'Sturdy Inu',
#  'PLSMRI': 'PULSE MRI',
#  'FlokiC': 'Floki Cash',
#  'LINU': 'Luna Inu',
#  'KOI': 'The Dragon Gate',
#  'KATSUDO': 'Katsudo Shashin',
#  'DIME': 'ParaDIME',
#  'QNT': 'Quant',
#  'DAO': 'DAO Maker',
#  'Alexey': 'Privacy',
#  'AGIX': 'SingularityNET Token',
#  'dEye': 'Decentralized Eye',
#  'nPLSZ': 'noPulse',
#  'GFT': 'GameFederation',
#  'YEET': 'YEET',
#  'DAI': 'Dai Stablecoin',
#  'J': 'Last Dragon Slayer',
#  'BEANS': 'DogeCoffee',
#  'DPTHOT': 'DeepThot',
#  'STARS': 'Mini-Stars',
#  'CLINU': 'Clean Inu',
#  'BLOCK-E': 'BLOCK-E',
#  'TERA': 'Terareum',
#  '$RTP': 'RatTrap',
#  'AGNI': 'The God of Fire',
#  'XI': 'Xi Token',
#  'PBR': 'PolkaBridge',
#  'PSAITAMA': 'PulseSaitama',
#  'ZORA': 'Zoracles',
#  'KAZU': 'KAZUMI',
#  'GMI': 'Gonna Make It',
#  'TSUNE': 'Dejitaru Kitsune',
#  'GVR': 'Grove Token',
#  'DFYN': 'DFYN Token',
#  'MIKASA': 'Mikasa',
#  'SHU': 'DejitaruShuraku',
#  '$TKD': 'Toxic Kings DAO',
#  'CELL': 'Cellframe Token',
#  'INUINU': 'Inu Inu',
#  'WALLY': 'Wallace',
#  '1936': 'Tasmania',
#  'BULLME': 'Bull Merge',
#  'APOCA': 'APOCALYPSE',
#  '🍞': 'Biscuits Inu',
#  'APE': 'ApeCoin',
#  'SIGMA': 'Degen',
#  'SENATE': 'SENATE',
#  'PLSD': 'PulseDogecoin',
#  'MAGMA': 'Floor Is Lava!',
#  'PPLS': 'PepePulse',
#  'SHINDEIRU': 'Omae Wa Mou',
#  'VRT': 'Vegan Rob Token',
#  'ELGD': 'Eleven Gold',
#  'CLAYMORE': 'Claymore',
#  'LAIKABANK': 'Laika Bank',
#  'ESP': 'Telepathy',
#  '$DROWN': 'Umibozu',
#  'MPI': 'MonkeyPox Inu',
#  'XOR': 'Sora Token',
#  'IC': 'InuCraft',
#  'YASUKE': 'Yasuke',
#  'SPUNK': 'Shiba Punkz',
#  'BELIEVE': 'NO COMMUNICATION',
#  'GOWLD': 'GOWLD',
#  'SHKI': 'Shkreli Inu',
#  '👘': 'KIMONO',
#  'AMPLIFI': 'Amplifi',
#  'ZKS': 'Zks',
#  '♾️': 'Simpson Inu',
#  'MKR': 'Maker Token',
#  'IMPACTXP': 'ImpactXP',
#  'Samael': 'Poison of God',
#  'SAUDISHIB': 'SAUDI SHIBA INU',
#  'KINIROB': 'KINIRO BANK',
#  'TEL': 'Telcoin',
#  'PLSL': 'PulseLiquid',
#  'LDO': 'Lido DAO Token',
#  'CRV': 'Curve DAO Token',
#  'GALA': 'Gala',
#  'KEK': 'kek',
#  'KAZE': 'Kamikaze',
#  '23': 'Number23',
#  '47RONIN': '47 Ronin',
#  '$CL': 'ChungaLungaCoin',
#  'Gold 1': 'Teh Golden One',
#  'FEG': 'FEGtoken',
#  'DIA': 'DIAToken',
#  'INU': 'Inu.',
#  'TheAD': 'The Akragas Decadrachm',
#  'TEHBANK': 'TEH BANK',
#  'TAKE': 'Takemikazuchi',
#  'GALAXY': 'Galaxy',
#  'BASS': 'Bear Assassin',
#  'CON': 'Conspiracy',
#  'PLCT': 'PULSECULT',
#  '2+2=5': 'The Ultimate Lie',
#  'HEDGY🐾': 'HEDGY🐾',
#  'YUMI': 'Dejitaru Yumi',
#  'Kryptos': 'Kryptos',
#  'PLSO': 'Pulse Okinami ',
#  'ZEETOX': 'Zeetox',
#  '$SHIBIYAKI': 'Shibiyaki Inu',
#  'FLY': 'Fly',
#  'BTFA': 'Banana Task Force Ape',
#  'QMALL': 'Qmall Token',
#  'MRI': 'Marshall Rogan Inu',
#  'ANALOS': 'ANALOS',
#  'DPX': 'Dopex Governance Token',
#  '$Kanemochi': 'Kanemochi',
#  'OPUL': 'OpulousToken',
#  'RAD': 'Radicle',
#  'BBC': 'Big Black Cock',
#  'BAL': 'Balancer',
#  'GRT': 'Graph Token',
#  '\U0001fa78': 'Pure Blood',
#  'LUFFY': 'LUFFY',
#  '$PLSK': '$PULSE KIBA',
#  'DDOA': 'Dokodemo Doa',
#  'SHIBZEUS': 'God of Slot',
#  'API3': 'API3',
#  'HMSB': 'Ho-Musubi',
#  'VDX': 'VADERX',
#  'CB': 'CloutBase',
#  'NFA': 'Not Financial Advice',
#  'AUDIO': 'Audius',
#  'MPulse': 'Musk Pulse',
#  'STAFFY': 'STAFFY INU',
#  'Lesbian🐠': 'Lesbian Fish',
#  'SAITATE': 'Saitate',
#  'Ly': 'Lilly Finance',
#  '$PALS': 'FlokiMarvin $Pals',
#  'GALI': 'GALILEO',
#  'HIKARI': 'Hikari',
#  'CUBE': 'Somnium Space Cubes',
#  'JIJI': 'Jiisan',
#  '$KING': 'KING WOJACK',
#  'DEZIK': 'Dezik',
#  'WORMHOLE': 'Wormhole',
#  'OINK': "A Piggy's Dream",
#  'FLOKIPAL': 'Floki Pal',
#  'ROUTE': 'Route',
#  'DPULSE': 'DARKPULSE',
#  'GLITCH': 'Glitch',
#  'KUCHISAKE': 'Kuchisake Onna',
#  'ETHGRAM': 'EthGram',
#  'DRAGOND': 'Dragon Discord',
#  '$PULSELON': 'PULSELON',
#  'LIVE': 'BULL&BEAR',
#  'ALTRUISM': 'ALTRUISM',
#  'BABYDOGE': 'BabyDoge Coin',
#  'TDOGE': 'Tornadoge',
#  'ZINU': 'Zombie Inu',
#  'UBT': 'UniBright',
#  '$MACC': 'Macc Money',
#  'RLY': 'Rally',
#  'WAGMIGAMES': 'WAGMI GAMES',
#  'REQ': 'Request Token',
#  'YOP': 'YOP',
#  'GUCCI': 'Gucci Coin',
#  'MANA': 'Decentraland MANA',
#  'ONLYCHADS': 'Only Chads',
#  'GSWAP': 'gameswap.org',
#  'TAWARA': 'Tawara Toda Monogatari',
#  'TrollFace': 'TrollFace',
#  'SYLO': 'Sylo',
#  'RBN': 'Ribbon',
#  'PERP': 'Perpetual',
#  'INUKAI': 'Inukai Takeru',
#  'OJ287': 'OJ 287',
#  'DG': 'Decentral Games',
#  'OCEAN': 'Ocean Token',
#  'Prospective': 'Prospective',
#  'Pyromania': 'BURN',
#  'PULMSI': 'Pulse Martin Shkreli Inu',
#  'HULK': 'HULK INU',
#  'BAKITA': 'BASEDAKITA',
#  'SERENITY': 'Moon',
#  'AYYLMAO': 'AYYLMAO',
#  'CLASSIFIED': 'Mar-A-Lago',
#  'SNACK': 'Snack',
#  'DEXT': 'DEXTools',
#  'POLS': 'PolkastarterToken',
#  'y6t5r': 'binohjuafgrve',
#  'STRADE': 'SnapTrade',
#  'SANI': 'Sanin Inu',
#  '0.2': 'Zero Point Two',
#  'HOWL': 'The Wolves Howl',
#  'HERMES': 'God Of Trade',
#  'VALU': 'Valueless',
#  'QANX': 'QANX Token',
#  'S-CATS': 'SUPERCATS',
#  '$iWATCH': 'Influencer Watch',
#  'TORCH': 'TORCH',
#  'Canto': 'Canto Utility Token',
#  'EBI': 'EBISU',
#  'CHINXI': 'Dejitaru Chinxi',
#  'VENDETTA': 'VEN',
#  'CANTO': 'Canto',
#  'KIBA': 'Kiba Inu',
#  'SFIRES': 'Static Fires',
#  'KLEE': 'KleeKai',
#  'CIMO': 'Cinnamoon',
#  'RACA': 'Radio Caca V2',
#  'LIGHT': 'Light Code',
#  'GRUFF': 'Grufford',
#  'PC': 'Pencoin',
#  'ANKR': 'Ankr Network',
#  'INV': 'Inverse DAO',
#  '$GRUUL': 'Dragon Killer',
#  'Meta': 'Metamorphosis',
#  'SHIFT': 'SHIFT',
#  '1929': 'Black Thursday',
#  'CRANEO': 'Craneo',
#  'BLT': 'Bloom Token',
#  'BlueSparrow': 'BlueSparrowToken',
#  'HIDDEN': 'The Ancient Rule',
#  'OKAMI': 'Okami',
#  'GMEE': 'GAMEE',
#  'SD': 'Stader',
#  'ATD': 'APETRADERS',
#  '$colR': 'colR Coin',
#  'PSHIB': 'PULSE SHIBA INU',
#  '🎏': 'Samurai Spirit',
#  'SEND': 'FULL SEND',
#  'XDB': 'digitalbits',
#  'MLT': 'Media Licensing Token',
#  'PEPE+': 'PepePlatinum',
#  'SLEUTH': 'Slothereum',
#  'XUSDP': 'XUSD Prime Coin',
#  'IKEUCHI': 'Dejitaru Ikeuchi',
#  'Shokunin': 'Shokunin',
#  'KIMBA': 'Kimba Inu',
#  'BSI': 'BurnShkreli',
#  'LOSTSKULLS': 'Lost Skulls',
#  '1INCH': '1INCH Token',
#  'ERN': '@EthernityChain $ERN Token',
#  'TREASURE': "Caishen's Treasure",
#  'CHZ': 'chiliZ',
#  'RYUZHIN': 'MizuRyu',
#  'KIN': 'Kakushi Burokku',
#  'PICKLE': 'PickleToken',
#  'TWINU': 'TWITTER INU',
#  'INFINITE': 'Ad Infinitum ',
#  'DEJISHIB': 'Dejitaru ShibaInu',
#  'VITM': 'Vitruvian Man',
#  'ENJ': 'Enjin Coin',
#  'ORN': 'Orion Protocol',
#  'BCT': 'BananaClubToken',
#  'ONNA': 'Onna-musha',
#  'CRO': 'CRO',
#  'dKUMA': 'KumaDex Token',
#  'UOS': 'Ultra Token',
#  'ALI': 'Artificial Liquid Intelligence Token',
#  'SERAPH': 'The Angelic Creation',
#  'HANK': 'Articles of Hankules',
#  'JIGSAW': 'JigsawToken',
#  'KOMPETE': 'KOMPETE Token',
#  'SCROH': 'SCRO Holdings',
#  '1984': 'The 1984',
#  'CERBERUS': 'Three-Headed Dog',
#  'TTM': 'To The Moon',
#  'VADER': 'Vader',
#  'SINU': 'ShikimoriInu',
#  'BHM': 'Baby Horseman',
#  'PHNX': 'The Phoenix',
#  'CHROMA': 'CHROMATOGRAPHY',
#  'MCC': 'MultiChainCapital',
#  'WPT': 'WPT Investing Corp',
#  'K10': 'KuCoin 10',
#  'LUNCH': 'Lunch',
#  'HOT': 'HoloToken',
#  'PIMP': 'PulseChimp',
#  'INFERNO': 'Disco Inferno',
#  'PUSH': 'Ethereum Push Notification Service',
#  'F9': 'Falcon 9',
#  'Musketeer': 'Musketeer',
#  'BAGS': 'Bagheera Saisho',
#  'MASK': 'Mask Network',
#  'RAI': 'Rai Reflex Index',
#  'PULSENOBI': 'Pulsenobi',
#  '👁': 'BLIND EYE',
#  'GLCH': 'Glitch',
#  'WRLD': 'NFT Worlds',
#  'DIP': 'Degens In Paradise',
#  'ANT': 'Aragon Network Token'}

# %%
#Created a dictionary with ticker: contact address to use in the price history API pull
ticker_contract_dict = dict(zip(coin_table_df.contract_ticker_symbol, coin_table_df.contract_address))
dict(zip(coin_table_df.contract_ticker_symbol, coin_table_df.contract_address))
# Out:
# {'USDC': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#  'USDT': '0xdac17f958d2ee523a2206206994597c13d831ec7',
#  'TSUKA': '0xc5fb36dd2fb59d3b98deff88425a3f425ee469ed',
#  'PLSF': '0x90f36d7bfba633f17eccc62ec31c58a9a3c04c2a',
#  'UFO': '0x249e38ea4102d0cf8264d3701f1a0e39c4f2dc3b',
#  'REKT': '0x0fd48023b21d1847b5532ed619c2ce3e552f9b07',
#  'SHIB': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce',
#  'CEL': '0xaaaebe6fe48e54f431b0c390cfaf0b017d09d42d',
#  'MOPS': '0x602f65bb8b8098ad804e99db6760fd36208cd967',
#  'HEX': '0x2b591e99afe9f32eaa6214f7b7629768c40eeb39',
#  'OSAKU': '0xcbccbb06f572df174a7da47684cdc28121fec421',
#  'X7m105': '0x06d5ca7c9accd15a87d4993a421b7e702bdbab20',
#  'MIZUCHI': '0xb444bbc38ab8683eca959d1fec4fbe7f6cdcb0cb',
#  'PLSS': '0x9e980d7bdab85f0d58b3d5823a24d84879451ab4',
#  'Okinami': '0x1c4853ec0d55e420002c5efabc7ed8e0ba7a4121',
#  'INUS': '0x39207d2e2feef178fbda8083914554c59d9f8c00',
#  'Mikaboshi': '0xae86f48c0b00f2a3eaef4ba4c23d17368f0f63f4',
#  'PEPE': '0x4a27e9aab8f8ba9de06766c8476ed1d16494e35f',
#  'LAIKA': '0x77f9cf0bd8c500cffdf420e72343893aecc2ec0b',
#  'MASKED': '0x8b55bc12d6077380f966122639ae6b6f42cbcc0c',
#  'LQNTY': '0xd1be6c91352e5afca7c0db69eaa390dbcbfca762',
#  'HDRN': '0x3819f64f282bf135d62168c1e513280daf905e06',
#  'PLST': '0x7b687d1112d31f16c02ac5f32cef40671aecd8bf',
#  'CULT': '0xf0f9d895aca5c8678f706fb8216fa22957685a13',
#  'RYU': '0x93b92b508c7a6dd9d0ccf3325f930f7ba42a004d',
#  'GALAXY': '0x2161a3d57c07355eb1fb49a32d3836573107a63f',
#  'BASS': '0xd2e06280eaa150f4fe2805ed0513a5cfe16a8b96',
#  'CON': '0x4b0f250345935b75b3582e3651ad3b53f2852dbf',
#  'PLCT': '0x689b765a01bd81dbe7bf95136f5bd9f89dfec91f',
#  '2+2=5': '0x55e9ecbc7d58b26d7c045d06e1767184cb5fb730',
#  'HEDGY🐾': '0x51c43d51b52f5abaca8d699e36a895950e8d6b70',
#  'YUMI': '0xb38c6f2a5e6c528ed0807b4b7ac536ceaf5c3c11',
#  'Kryptos': '0xd2b49ba5c0685fabbe4a1a5da0c869b737746595',
#  'PLSO': '0x05cb56c2e56b969188cdcfc69c9827af4cceb4de',
#  'ZEETOX': '0x9b82ece6bb6f23a5e4e7b280073fa7948a3d5471',
#  '$SHIBIYAKI': '0xace4615183c20fff2ddae7cdcae97c2f96551516',
#  'FLY': '0x53c87b65629419d76098fc54db81e03ada5f1421',
#  'BTFA': '0xc631be100f6cf9a7012c23de5a6ccb990eafc133',
#  'QMALL': '0x2217e5921b7edfb4bb193a6228459974010d2198',
#  'MRI': '0x0913ddae242839f8995c0375493f9a1a3bddc977',
#  'ANALOS': '0xa8628541f69b999f81ac5535e28271500919cfa3',
#  'DPX': '0xeec2be5c91ae7f8a338e1e5f3b5de49d07afdc81',
#  '$Kanemochi': '0x4ac305bc46deae3687147ac387e800ff3034de54',
#  'OPUL': '0x80d55c03180349fff4a229102f62328220a96444',
#  'RAD': '0x31c8eacbffdd875c74b94b077895bd78cf1e64a3',
#  'BBC': '0xe07d437f4395830450b214604afa46f1a2efd374',
#  'BAL': '0xba100000625a3754423978a60c9317c58a424e3d',
#  'GRT': '0xc944e90c64b2c07662a292be6244bdf05cda44a7',
#  '\U0001fa78': '0x9fee682d6375f61da1bcd5e160ec2cc39b1f5b56',
#  'LUFFY': '0x7121d00b4fa18f13da6c2e30d19c04844e6afdc8',
#  '$PLSK': '0x166b2a6ad22aa7eab26b6b4b2e10cbc1d6a05a71',
#  'DDOA': '0x7a09799a66984be8b1b94ae6fe9ed3e595649acb',
#  'SHIBZEUS': '0xa012cc4e2ef35590af5e14e926e30190e880a3bf',
#  'API3': '0x0b38210ea11411557c13457d4da7dc6ea731b88a',
#  'HMSB': '0xc8723c9428f4324fda2a4faf181d956ded3faeff',
#  'VDX': '0x535e9604afad7441556ded9cca31721e89598eda',
#  'CB': '0x2686191936fe1bc05aa5e2e7b19f639ebf8cd018',
#  'NFA': '0x2094f4a923e66809ceb5656ba87e7bfd5f8fcd7e',
#  'AUDIO': '0x18aaa7115705e8be94bffebde57af9bfc265b998',
#  'MPulse': '0x0ce41262adc11dd1621140344fd7f4dd0129bcc4',
#  'STAFFY': '0x54025988881a697a12da1499423c92b7b841d852',
#  'Lesbian🐠': '0xfd229821fcb54a68af17fda4ca87446d3641526d',
#  'SAITATE': '0x6fcf107ca12235ef4bbfe90e0f5b3bda6104906f',
#  'Ly': '0x8686525d6627a25c68de82c228448f43c97999f2',
#  '$PALS': '0x5b6a35c90d7f7d25899ee52f1aa63344a5be786f',
#  'GALI': '0x40a11f82a8469c8dc015ba74438536584978d63c',
#  'HIKARI': '0x9d3bd85c4b70098600fd488ca5702ce2f6e36282',
#  'CUBE': '0xdf801468a808a32656d2ed2d2d80b72a129739f4',
#  'JIJI': '0x29fb9cbaf90e3a7e786b3006a7539651810f6aad',
#  '$KING': '0x0083e312b10016e366cdaf60e392a5bf8d663669',
#  'DEZIK': '0xa14136bd9bedf4b4854159f07a800aee6a8234c0',
#  'WORMHOLE': '0x79485c10d3f0b2c08caf8f00fbcfb48613eb2bc1',
#  'OINK': '0xb67a21c3825b2b7f71e5786e9a6e08f8242d7314',
#  'FLOKIPAL': '0x02259ee03cd10c91c5d0c82e30d8b3e63431e415',
#  'ROUTE': '0x16eccfdbb4ee1a85a33f3a9b21175cd7ae753db4',
#  'DPULSE': '0xf2bc71785327f610f8325f67ebcc2ff68ff6cf4c',
#  'GLITCH': '0xbb2f20fc2ab2bf794767f43b957fea39f8ec8f92',
#  'KUCHISAKE': '0x5257f642c0cc3048883e9879f15f9c9855b10d2e',
#  'ETHGRAM': '0x40f85830194467c27028224cebabd539a77d701b',
#  'DRAGOND': '0x84d6a7cd023cd970e1d22721ffe8c11ee1ec3c1b',
#  '$PULSELON': '0xd79a1d96dcafed127ee571461f369accb0b92d92',
#  'LIVE': '0x67873a14804e9db31de66601e8f81fdef0169bee',
#  'ALTRUISM': '0x200fe56fedadf1cbb082d0936b2dfe1fc64c3fa3',
#  'BABYDOGE': '0xac8e13ecc30da7ff04b842f21a62a1fb0f10ebd5',
#  'TDOGE': '0xf4547e2914086f2749066b1de000d0ead4dcaeee',
#  'ZINU': '0xc50ef449171a51fbeafd7c562b064b6471c36caa',
#  'UBT': '0x8400d94a5cb0fa0d041a3788e395285d61c9ee5e',
#  '$MACC': '0x3466b4c9e2abc189b59ad64af247619df10c7e7b',
#  'RLY': '0xf1f955016ecbcd7321c7266bccfb96c68ea5e49b',
#  'WAGMIGAMES': '0x3b604747ad1720c01ded0455728b62c0d2f100f0',
#  'REQ': '0x8f8221afbb33998d8584a2b05749ba73c37a938a',
#  'YOP': '0xae1eaae3f627aaca434127644371b67b18444051',
#  'GUCCI': '0x438b04a00f72ca0739b5b92f0abf34e8e9506eb2',
#  'MANA': '0x0f5d2fb29fb7d3cfee444a200298f468908cc942',
#  'ONLYCHADS': '0xe9609f260e557aae3c8c76ca7fc29b60385acb94',
#  'GSWAP': '0xaac41ec512808d64625576eddd580e7ea40ef8b2',
#  'TAWARA': '0x53588c29ea77d63751b7149419696bda9311671b',
#  'TrollFace': '0xb3c7c24ec02b6fc982fddfe4d3a5ef3b2528100d',
#  'SYLO': '0xf293d23bf2cdc05411ca0eddd588eb1977e8dcd4',
#  'RBN': '0x6123b0049f904d730db3c36a31167d9d4121fa6b',
#  'PERP': '0xbc396689893d065f41bc2c6ecbee5e0085233447',
#  'INUKAI': '0x54ecc8fe442e20f92f6c000e6dacc874761a1c0f',
#  'INV': '0x41d5d79431a913c4ae7d69a668ecdfe5ff9dfb68',
#  '$GRUUL': '0x256d8b5f8bfedc0aeefea55f18c1db022f659737',
#  'Meta': '0x2a95859780c8103059b62e417cc8532348fc7889',
#  'SHIFT': '0x5d554e71744aada1738261f64e3a2c6dd8a7def1',
#  '1929': '0x7d75462130e125506ccada5493332e5db80d1ca9',
#  'CRANEO': '0xcdc6976f2be142cc775d6db6f3227a198c913c41',
#  'BLT': '0x107c4504cd79c5d2696ea0030a8dd4e92601b82e',
#  'BlueSparrow': '0x24ccedebf841544c9e6a62af4e8c2fa6e5a46fde',
#  'HIDDEN': '0x224b13a63d728361352b849d83559468563855e1',
#  'OKAMI': '0x4f70dab258148a43d7e3a524b8b130f9d5edf8f1',
#  'GMEE': '0xd9016a907dc0ecfa3ca425ab20b6b785b42f2373',
#  'SD': '0x30d20208d987713f46dfd34ef128bb16c404d10f',
#  'ATD': '0x7d90e89e5624a73595d12d8cd755fa5a061eeb1a',
#  '$colR': '0x14b40ad2eba6c1b31db2ba817b07578afb414415',
#  'PSHIB': '0x3705795cd1b6d5bb59755c1c65e1c3e17e999707',
#  '🎏': '0xc92a41b59abe9ecae0f1d84c5e3933ac38d32e4c',
#  'SEND': '0x528f5f24fac9f86023f209a0f9cd00852d9e01d2',
#  'XDB': '0xb9eefc4b0d472a44be93970254df4f4016569d27',
#  'MLT': '0x9506d37f70eb4c3d79c398d326c871abbf10521d',
#  'PEPE+': '0xc78ff2fc479315558db5aa960d612e8421da8fe8',
#  'SLEUTH': '0x8ca005f8bfa8c165413c9b9761d4b29c6dbc61ec',
#  'XUSDP': '0xa1f7c9c6d19e2d0bf20729cb0bf03338a90bed9b',
#  'IKEUCHI': '0x0f387e1e11dfc3763278173ef9d1961d9c8aafff',
#  'Shokunin': '0xf25b416d0b1a2613bd0993409e9495cc179d3cfb',
#  'KIMBA': '0xc8f74daedd3aa6550e5ac799fedd549c9d094398',
#  'BSI': '0x2c1c431475e9aa14b6043b19d39ff2c89ec770a6',
#  'LOSTSKULLS': '0x9dee78e4bfbebf6101eb67d097be77c5c5769ee5',
#  '1INCH': '0x111111111117dc0aa78b770fa6a738034120c302',
#  'ERN': '0xbbc2ae13b23d715c30720f079fcd9b4a74093505',
#  'TREASURE': '0x1fabc4b66b73fec921d749ebeed75379762c1baf',
#  'CHZ': '0x3506424f91fd33084466f402d5d97f05f8e3b4af',
#  'RYUZHIN': '0x6c397cfa7ad182280b22ca84bc52991224f9558b',
#  'KIN': '0xda55fecbab9214bfb9e555a55797071fbd16623b',
#  'PICKLE': '0x429881672b9ae42b8eba0e26cd9c73711b891ca5',
#  'TWINU': '0xcc3b44e6acdbecdb8ea3ed4dbc6bd713c44a8bc4',
#  'INFINITE': '0x8ab928a2b639a12f91bda68bc10f890efd6538ed',
#  'DEJISHIB': '0x795f3d1babba1fe269cf778e02600972ee461103',
#  'VITM': '0xe34d585aa03f1dbcd6d37254b94d7a8557fffdc3',
#  'ENJ': '0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c',
#  'ORN': '0x0258f474786ddfd37abce6df6bbb1dd5dfc4434a',
#  'BCT': '0x350d3f0f41b5b21f0e252fe2645ae9d55562150a',
#  'ONNA': '0x9d0cf1fea03d83f11775dd19432d086641765fa9',
#  'CRO': '0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b',
#  'dKUMA': '0x3f5dd1a1538a4f9f82e543098f01f22480b0a3a8',
#  'UOS': '0xd13c7342e1ef687c5ad21b27c2b65d772cab5c8c',
#  'ALI': '0x6b0b3a982b4634ac68dd83a4dbf02311ce324181',
#  'SERAPH': '0xd01075d39fd760a52932da3bde0474d3f5500c3c',
#  'HANK': '0x1b3755b07237adbbbe5b4488094ffc4781d3a0dc',
#  'JIGSAW': '0xb0d47dd82fb8facb1bc4ba534a836b545ad97d2b',
#  'KOMPETE': '0x1e0b2992079b620aa13a7c2e7c88d2e1e18e46e9',
#  'SCROH': '0x73a058da53220d25bcb2c4cb8ff8520626ea26e7',
#  '1984': '0x447f52aff7e85ded889ae64efb82aa3bb4a3b644',
#  'CERBERUS': '0xb27f7244b3b71ed4005290bad8fcd6a3cd35eab4',
#  'TTM': '0x22bfe3a417d129841c7f7a21252d1368f90e962b',
#  'VADER': '0x2602278ee1882889b946eb11dc0e810075650983',
#  'SINU': '0x2ea236fbfc9d2af44e257c36c13200058740d27f',
#  'BHM': '0x8aa98c8415873df527faa4bbd543bb863c2f3b28',
#  'PHNX': '0xf38e92403ceec561d099f6883bb2a9fa208e51c2',
#  'CHROMA': '0x9baa26e5a8da5a7c65790361b5969def5e8351f7',
#  'MCC': '0xc146b7cdbaff065090077151d391f4c96aa09e0c',
#  'WPT': '0x4fd51cb87ffefdf1711112b5bd8ab682e54988ea',
#  'K10': '0x21a84ba0a9aef9d6de86bf5b19386f22ab753e08',
#  'LUNCH': '0xb5a546d227544d7f563d9d6ecf4d25bce7158179',
#  'HOT': '0x6c6ee5e31d828de241282b9606c8e98ea48526e2',
#  'PIMP': '0x6640d3a51caf48db48ec6c57a38dbd9c374e502b',
#  'INFERNO': '0xd137d6db26a4db26b22f10066a34de23373870e8',
#  'PUSH': '0xf418588522d5dd018b425e472991e52ebbeeeeee',
#  'F9': '0x38a94e92a19e970c144ded0b2dd47278ca11cc1f',
#  'Musketeer': '0xf09139dd83e2e92faad54ff3b4b7cbe057101786',
#  'BAGS': '0xbfff8b983f049be54c1aa7493615957acd98b0cc',
#  'MASK': '0x69af81e73a73b40adf4f3d4223cd9b1ece623074',
#  'RAI': '0x03ab458634910aad20ef5f1c8ee96f1d6ac54919',
#  'PULSENOBI': '0x8b828f71492b4da7f83ac3480de501110e32ec6a',
#  '👁': '0xb8110896d6f6055bb3da35904b8bf040064defd9',
#  'GLCH': '0x038a68ff68c393373ec894015816e33ad41bd564',
#  'WRLD': '0xd5d86fc8d5c0ea1ac1ac5dfab6e529c9967a45e9',
#  'DIP': '0xa8f340358fc1f87bafb61efdae4e62d5501b571e',
#  'ANT': '0xa117000000f279d81a1d3cc75430faa017fa5a2e'}
